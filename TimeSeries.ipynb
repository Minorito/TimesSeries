# %% [markdown]
# <a href="https://colab.research.google.com/github/Minorito/TimesSeries/blob/main/TimeSeries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Alucar - Analisando Vendas

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
alucar = pd.read_csv('alucar.csv')

# %%
alucar.head()
# Out:
#           mes  vendas
# 0  2017-01-31      10
# 1  2017-02-28      20
# 2  2017-03-31      33
# 3  2017-04-30      47
# 4  2017-05-31      63

# %%
print('Quantidade de Linhas e Colunas: ', alucar.shape)
# Out:
# Quantidade de Linhas e Colunas:  (24, 2)

# %%
print('Quantidade de dados nulos:', alucar.isna().sum().sum())
# Out:
# Quantidade de dados nulos: 0

# %%
alucar.dtypes
# Out:
# mes       object
# vendas     int64
# dtype: object

# %%
alucar['mes'] = pd.to_datetime(alucar['mes'])
alucar.dtypes
# Out:
# mes       datetime64[ns]
# vendas             int64
# dtype: object

# %%
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
print(sns.__version__)
# Out:
# 0.12.2

# %%
sns.lineplot(x='mes', y='vendas', data=alucar)
# Out:
# <Axes: xlabel='mes', ylabel='vendas'>

# %%
sns.set_palette('Accent')
sns.set_style('darkgrid')
ax = sns.lineplot(x='mes', y='vendas', data=alucar)
ax.figure.set_size_inches(12,6)
ax.set_title('Vendas Alucar de 2017 e 2018', loc='left', fontsize=18)
ax.set_xlabel('Tempo', fontsize=14)
ax.set_ylabel('Vendas (R$)', fontsize=14)
ax=ax

# %%
alucar['aumento'] = alucar['vendas'].diff()
alucar.head()
# Out:
#          mes  vendas  aumento
# 0 2017-01-31      10      NaN
# 1 2017-02-28      20     10.0
# 2 2017-03-31      33     13.0
# 3 2017-04-30      47     14.0
# 4 2017-05-31      63     16.0

# %%
sns.set_palette('Accent')
sns.set_style('darkgrid')
ax = sns.lineplot(x='mes', y='aumento', data=alucar)
ax.figure.set_size_inches(12,6)
ax.set_title('Aumento das Vendas Alucar de 2017 e 2018', loc='left', fontsize=18)
ax.set_xlabel('Tempo', fontsize=14)
ax.set_ylabel('Aumento', fontsize=14)
ax=ax

# %%
def plotar(titulo, labelx, labely, x, y, dataset):
  sns.set_palette('Accent')
  sns.set_style('darkgrid')
  ax = sns.lineplot(x=x, y=y, data=dataset)
  ax.figure.set_size_inches(12,6)
  ax.set_title(titulo, loc='left', fontsize=18)
  ax.set_xlabel(labelx, fontsize=14)
  ax.set_ylabel(labely, fontsize=14)
  ax=ax

# %%
plotar('Aumento das Vendas Alucar de 2017 e 2018', 'Tempo', 'Aumento', 'mes', 'aumento', alucar)

# %%
alucar['aceleracao'] = alucar['aumento'].diff()

# %%
plotar('Aceleração das Vendas Alucar de 2017 e 2018', 'Tempo', 'Aceleração', 'mes', 'aceleracao', alucar)

# %%
plt.figure(figsize=(16,12))
ax = plt.subplot(3, 1, 1)
ax.set_title('Análise da Alucar de 2017 a 2018', fontsize=18, loc='left')
sns.lineplot(x='mes', y='vendas', data=alucar)
ax = plt.subplot(3, 1, 2)
sns.lineplot(x='mes', y='aumento', data=alucar)
ax = plt.subplot(3, 1, 3)
sns.lineplot(x='mes', y='aceleracao', data=alucar)
ax=ax

# %%
#Plot Intereativo
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import plotly.offline as pyo

# Create traces
trace0 = go.Scatter(x=alucar['mes'], y=alucar['vendas'], mode='lines', name='Vendas')
trace1 = go.Scatter(x=alucar['mes'], y=alucar['aumento'], mode='lines', name='Aumento')
trace2 = go.Scatter(x=alucar['mes'], y=alucar['aceleracao'], mode='lines', name='Aceleração')

# Create subplots
fig = make_subplots(rows=3, cols=1, shared_xaxes=True)

# Add traces to subplots
fig.add_trace(trace0, row=1, col=1)
fig.add_trace(trace1, row=2, col=1)
fig.add_trace(trace2, row=3, col=1)

# Update layout
fig.update_layout(
    title='Análise da Alucar de 2017 a 2018',
    height=600,
    width=800
)

# Show plot
pyo.iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3a13b4c1-6d25-41a8-8b1b-7ef952424e73" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a13b4c1-6d25-41a8-8b1b-7ef952424e73")) {                    Plotly.newPlot(                        "3a13b4c1-6d25-41a8-8b1b-7ef952424e73",                        [{"mode":"lines","name":"Vendas","x":["2017-01-31T00:00:00","2017-02-28T00:00:00","2017-03-31T00:00:00","2017-04-30T00:00:00","2017-05-31T00:00:00","2017-06-30T00:00:00","2017-07-31T00:00:00","2017-08-31T00:00:00","2017-09-30T00:00:00","2017-10-31T00:00:00","2017-11-30T00:00:00","2017-12-31T00:00:00","2018-01-31T00:00:00","2018-02-28T00:00:00","2018-03-31T00:00:00","2018-04-30T00:00:00","2018-05-31T00:00:00","2018-06-30T00:00:00","2018-07-31T00:00:00","2018-08-31T00:00:00","2018-09-30T00:00:00","2018-10-31T00:00:00","2018-11-30T00:00:00","2018-12-31T00:00:00"],"xaxis":"x","y":[10,20,33,47,63,81,101,124,148,174,201,230,261,293,326,362,400,440,483,527,573,621,670,721],"yaxis":"y","type":"scatter"},{"mode":"lines","name":"Aumento","x":["2017-01-31T00:00:00","2017-02-28T00:00:00","2017-03-31T00:00:00","2017-04-30T00:00:00","2017-05-31T00:00:00","2017-06-30T00:00:00","2017-07-31T00:00:00","2017-08-31T00:00:00","2017-09-30T00:00:00","2017-10-31T00:00:00","2017-11-30T00:00:00","2017-12-31T00:00:00","2018-01-31T00:00:00","2018-02-28T00:00:00","2018-03-31T00:00:00","2018-04-30T00:00:00","2018-05-31T00:00:00","2018-06-30T00:00:00","2018-07-31T00:00:00","2018-08-31T00:00:00","2018-09-30T00:00:00","2018-10-31T00:00:00","2018-11-30T00:00:00","2018-12-31T00:00:00"],"xaxis":"x2","y":[null,10.0,13.0,14.0,16.0,18.0,20.0,23.0,24.0,26.0,27.0,29.0,31.0,32.0,33.0,36.0,38.0,40.0,43.0,44.0,46.0,48.0,49.0,51.0],"yaxis":"y2","type":"scatter"},{"mode":"lines","name":"Acelera\u00e7\u00e3o","x":["2017-01-31T00:00:00","2017-02-28T00:00:00","2017-03-31T00:00:00","2017-04-30T00:00:00","2017-05-31T00:00:00","2017-06-30T00:00:00","2017-07-31T00:00:00","2017-08-31T00:00:00","2017-09-30T00:00:00","2017-10-31T00:00:00","2017-11-30T00:00:00","2017-12-31T00:00:00","2018-01-31T00:00:00","2018-02-28T00:00:00","2018-03-31T00:00:00","2018-04-30T00:00:00","2018-05-31T00:00:00","2018-06-30T00:00:00","2018-07-31T00:00:00","2018-08-31T00:00:00","2018-09-30T00:00:00","2018-10-31T00:00:00","2018-11-30T00:00:00","2018-12-31T00:00:00"],"xaxis":"x3","y":[null,null,3.0,1.0,2.0,2.0,2.0,3.0,1.0,2.0,1.0,2.0,2.0,1.0,1.0,3.0,2.0,2.0,3.0,1.0,2.0,2.0,1.0,2.0],"yaxis":"y3","type":"scatter"}],                        {"height":600,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0 ...

# %%
def plot_comparacao(x, y1, y2, y3, dataset, titulo):
  plt.figure(figsize=(16,12))
  ax = plt.subplot(3, 1, 1)
  ax.set_title(titulo, fontsize=18, loc='left')
  sns.lineplot(x=x, y=y1, data=dataset)
  ax = plt.subplot(3, 1, 2)
  sns.lineplot(x=x, y=y2, data=dataset)
  ax = plt.subplot(3, 1, 3)
  sns.lineplot(x=x, y=y3, data=dataset)
  ax=ax

# %%
plot_comparacao('mes', 'vendas', 'aumento', 'aceleracao', alucar,'Análise das Vendas da Alucar de 2017 e 2018')

# %%
from pandas.plotting import autocorrelation_plot

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação das Vendas', fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(alucar['vendas'])
ax=ax

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação das Aumento', fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(alucar['aumento'][1:])
ax=ax

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação das Aceleração', fontsize=18, x=0.26, y=0.95)
autocorrelation_plot(alucar['aceleracao'][2:])
ax=ax

# %% [markdown]
# #Alucar - Analisando Assinantes da Newsletter

# %%
assinantes = pd.read_csv('newsletter_alucar.csv')

# %%
assinantes.head()
# Out:
#           mes  assinantes
# 0  2017-01-31           0
# 1  2017-02-28          10
# 2  2017-03-31          21
# 3  2017-04-30          34
# 4  2017-05-31          49

# %%
assinantes.dtypes
# Out:
# mes           object
# assinantes     int64
# dtype: object

# %%
print('Quantidade de linhas e colunas:', assinantes.shape)
print('Quantidade de dados nulos:', assinantes.isna().sum().sum())
# Out:
# Quantidade de linhas e colunas: (24, 2)
# Quantidade de dados nulos: 0

# %%
assinantes['mes'] = pd.to_datetime(assinantes['mes'])
assinantes.dtypes
# Out:
# mes           datetime64[ns]
# assinantes             int64
# dtype: object

# %%
assinantes['aumento'] = assinantes['assinantes'].diff()
assinantes['aceleracao'] = assinantes['aumento'].diff()
assinantes.head()
# Out:
#          mes  assinantes  aumento  aceleracao
# 0 2017-01-31           0      NaN         NaN
# 1 2017-02-28          10     10.0         NaN
# 2 2017-03-31          21     11.0         1.0
# 3 2017-04-30          34     13.0         2.0
# 4 2017-05-31          49     15.0         2.0

# %%
plot_comparacao('mes', 'assinantes','aumento', 'aceleracao', assinantes, 'Análise de Assinantes da Newsletter')

# %% [markdown]
# #Chocolura - analisando as Vendas

# %%
chocolura = pd.read_csv('chocolura.csv')
chocolura.head()
# Out:
#        mes  vendas
# 0  2017-01     210
# 1  2017-02     185
# 2  2017-03     209
# 3  2017-04     280
# 4  2017-05     211

# %%
chocolura.dtypes
# Out:
# mes       object
# vendas     int64
# dtype: object

# %%
chocolura['mes'] = pd.to_datetime(chocolura['mes'])
chocolura.dtypes
# Out:
# mes       datetime64[ns]
# vendas             int64
# dtype: object

# %%
print('Quantidade de Linhas e Colunas:', chocolura.shape)
print('Quantidade de dados nulos', chocolura.isna().sum().sum())
# Out:
# Quantidade de Linhas e Colunas: (24, 2)
# Quantidade de dados nulos 0

# %%
chocolura['aumento'] = chocolura['vendas'].diff()
chocolura['aceleracao'] = chocolura['aumento'].diff()

# %%
plot_comparacao('mes', 'vendas', 'aumento', 'aceleracao', chocolura, 'Análise Chocolura de 2017 a 2018')

# %% [markdown]
# #Chocolura - Vendas Diárias (Outubro e Novembro)

# %%
vendas_por_dia = pd.read_csv('vendas_por_dia.csv')
vendas_por_dia.head()
# Out:
#           dia  vendas
# 0  2018-10-01      50
# 1  2018-10-02      48
# 2  2018-10-03      56
# 3  2018-10-04      50
# 4  2018-10-05      51

# %%
print('Quantidade de Linhas e Colunas:', vendas_por_dia.shape)
print('Quantidade de dados nulos', vendas_por_dia.isna().sum().sum())
# Out:
# Quantidade de Linhas e Colunas: (61, 2)
# Quantidade de dados nulos 0

# %%
chocolura.dtypes
# Out:
# mes           datetime64[ns]
# vendas                 int64
# aumento              float64
# aceleracao           float64
# dtype: object

# %%
vendas_por_dia['dia'] = pd.to_datetime(vendas_por_dia['dia'])
vendas_por_dia.dtypes
# Out:
# dia       datetime64[ns]
# vendas             int64
# dtype: object

# %%
vendas_por_dia['aumento'] = vendas_por_dia['vendas'].diff()
vendas_por_dia['aceleracao'] = vendas_por_dia['aumento'].diff()

# %%
plot_comparacao('dia', 'vendas', 'aumento', 'aceleracao', vendas_por_dia, 'Análise Vendas por dia Outubro e Novembro')

# %% [markdown]
# **Analisando a Sazonalidade**

# %%
vendas_por_dia['dia_da_semana'] = vendas_por_dia ['dia'].dt.day_name()

# %%
vendas_por_dia.head(7)
# Out:
#          dia  vendas  aumento  aceleracao dia_da_semana
# 0 2018-10-01      50      NaN         NaN        Monday
# 1 2018-10-02      48     -2.0         NaN       Tuesday
# 2 2018-10-03      56      8.0        10.0     Wednesday
# 3 2018-10-04      50     -6.0       -14.0      Thursday
# 4 2018-10-05      51      1.0         7.0        Friday
# 5 2018-10-06      18    -33.0       -34.0      Saturday
# 6 2018-10-07      20      2.0        35.0        Sunday

# %%
vendas_por_dia['dia_da_semana'].unique()
# Out:
# array(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday',
#        'Sunday'], dtype=object)

# %%
dias_traduzidos = {'Monday': 'Segunda', 'Tuesday' : 'Terça', 'Wednesday':'Quarta', 
                   'Thursday':'Quinta', 'Friday':'Sexta', 'Saturday':'Sábado', 'Sunday':'Domingo'}

# %%
vendas_por_dia['dia_da_semana'] = vendas_por_dia['dia_da_semana'].map(dias_traduzidos)
vendas_por_dia.head(14)
# Out:
#           dia  vendas  aumento  aceleracao dia_da_semana
# 0  2018-10-01      50      NaN         NaN       Segunda
# 1  2018-10-02      48     -2.0         NaN         Terça
# 2  2018-10-03      56      8.0        10.0        Quarta
# 3  2018-10-04      50     -6.0       -14.0        Quinta
# 4  2018-10-05      51      1.0         7.0         Sexta
# 5  2018-10-06      18    -33.0       -34.0        Sábado
# 6  2018-10-07      20      2.0        35.0       Domingo
# 7  2018-10-08      50     30.0        28.0       Segunda
# 8  2018-10-09      53      3.0       -27.0         Terça
# 9  2018-10-10      56      3.0         0.0        Quarta
# 10 2018-10-11      40    -16.0       -19.0        Quinta
# 11 2018-10-12      15    -25.0        -9.0         Sexta
# 12 2018-10-13      14     -1.0        24.0        Sábado
# 13 2018-10-14      17      3.0         4.0       Domingo

# %% [markdown]
# **Agrupando os dias**

# %%
vendas_agrupadas = vendas_por_dia.groupby('dia_da_semana')['vendas', 'aumento', 'aceleracao'].mean().round()

# %%
vendas_agrupadas
# Out:
#                vendas  aumento  aceleracao
# dia_da_semana
# Domingo          19.0      3.0        31.0
# Quarta           53.0      1.0         2.0
# Quinta           51.0     -2.0        -3.0
# Segunda          52.0     34.0        31.0
# Sexta            45.0     -7.0        -5.0
# Sábado           16.0    -28.0       -20.0
# Terça            52.0     -1.0       -34.0

# %% [markdown]
# **Correlação das Vendas Diárias**

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação das Vendas Diárias', fontsize=18, x=0.3, y=0.95)
autocorrelation_plot(vendas_por_dia['vendas'])
ax=ax

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação do Aumento das Vendas Diárias', fontsize=18, x=0.35, y=0.95)
autocorrelation_plot(vendas_por_dia['aumento'][1:])
ax=ax

# %%
ax = plt.figure(figsize=(12,6))
ax.suptitle('Correlação da Aceleração das Vendas Diárias', fontsize=18, x=0.35, y=0.95)
autocorrelation_plot(vendas_por_dia['aceleracao'][2:])
ax=ax

# %% [markdown]
# #Cafelura - Análise de Vendas

# %%
cafelura = pd.read_csv('cafelura.csv')

# %%
cafelura.head()
# Out:
#           mes  vendas
# 0  2017-01-31     880
# 1  2017-02-28    1600
# 2  2017-03-31    3240
# 3  2017-04-30    3840
# 4  2017-05-31    5670

# %%
cafelura.dtypes
# Out:
# mes       object
# vendas     int64
# dtype: object

# %%
cafelura['mes'] = pd.to_datetime(cafelura['mes'])

# %%
cafelura.dtypes
# Out:
# mes       datetime64[ns]
# vendas             int64
# dtype: object

# %%
print('Quantidade de Linhas e Colunas:', cafelura.shape)
print('Quantidade de dados nulos', cafelura.isna().sum().sum())
# Out:
# Quantidade de Linhas e Colunas: (24, 2)
# Quantidade de dados nulos 0

# %%
plotar('Vendas da Cafelura de 2017 a 2018', 'Tempo', 'Vendas', 'mes', 'vendas', cafelura)

# %%
quantidade_de_dias_de_fds = pd.read_csv('dias_final_de_semana.csv')

# %%
quantidade_de_dias_de_fds.head()
# Out:
#    quantidade_de_dias
# 0                   8
# 1                   8
# 2                  10
# 3                   8
# 4                   9

# %%
quantidade_de_dias_de_fds['quantidade_de_dias'].values
# Out:
# array([ 8,  8, 10,  8,  9,  9,  8, 10,  8,  8, 10,  8,  9,  8,  9,  8, 10,
#         8,  8, 10,  8,  9,  9,  8])

# %%
cafelura['vendas_normalizadas'] = cafelura['vendas']/quantidade_de_dias_de_fds['quantidade_de_dias'].values
cafelura.head()
# Out:
#          mes  vendas  vendas_normalizadas
# 0 2017-01-31     880                110.0
# 1 2017-02-28    1600                200.0
# 2 2017-03-31    3240                324.0
# 3 2017-04-30    3840                480.0
# 4 2017-05-31    5670                630.0

# %%
plotar('Vendas Normalizadas da Cafelura de 2017 a 2018', 'Tempo', 'Vendas Normalizadas', 'mes', 'vendas_normalizadas', cafelura)

# %%
plt.figure(figsize=(12,8))
ax=plt.subplot(2,1,1)
ax.set_title('Vendas Cafelura 2017 e 2018', fontsize=18)
sns.lineplot(x='mes', y='vendas', data=cafelura)
ax=plt.subplot(2,1,2)
ax.set_title('Vendas normalizadas Cafelura 2017 e 2018', fontsize=18)
sns.lineplot(x='mes', y='vendas_normalizadas', data=cafelura)
ax=ax

# %% [markdown]
# #Statsmodels

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
resultado = seasonal_decompose(chocolura['vendas'],  period=2)
ax = resultado.plot()

# %%
observacao = resultado.observed
tendencia = resultado.trend
sazonalidade = resultado.seasonal
ruido = resultado.resid

# %%
data = ({
       'observacao':observacao,
       'tendencia':tendencia, 
       'sazonalidade':sazonalidade,
       'ruido':ruido
})
resultado = pd.DataFrame(data)
resultado.head()
# Out:
#    observacao  tendencia  sazonalidade      ruido
# 0       210.0        NaN    -13.386364        NaN
# 1       185.0     197.25     13.386364 -25.636364
# 2       209.0     220.75    -13.386364   1.636364
# 3       280.0     245.00     13.386364  21.613636
# 4       211.0     250.50    -13.386364 -26.113636

# %%
plot_comparacao(resultado.index, 'observacao', 'tendencia', 'sazonalidade', resultado, 'Exemplo de Statsmodels')

# %% [markdown]
# #Alucel - Análise de Vendas

# %%
alucel = pd.read_csv('alucel.csv')

# %%
alucel.head()
# Out:
#           dia   vendas
# 0  2018-10-01  1374.83
# 1  2018-10-02  2185.69
# 2  2018-10-03  1860.36
# 3  2018-10-04  1939.02
# 4  2018-10-05  1946.17

# %%
alucel.dtypes
# Out:
# dia        object
# vendas    float64
# dtype: object

# %%
alucel['dia'] = pd.to_datetime(alucel['dia'])
alucel.dtypes
# Out:
# dia       datetime64[ns]
# vendas           float64
# dtype: object

# %%
print('Quantidade de linhas e colunas:', alucel.shape)
print('Quantidade de dados nulos:', alucel.isna().sum().sum())
# Out:
# Quantidade de linhas e colunas: (61, 2)
# Quantidade de dados nulos: 0

# %%
alucel ['aumento'] = alucel ['vendas'].diff()
alucel ['aceleracao'] = alucel ['aumento'].diff()

# %%
alucel.head()
# Out:
#          dia   vendas  aumento  aceleracao
# 0 2018-10-01  1374.83      NaN         NaN
# 1 2018-10-02  2185.69   810.86         NaN
# 2 2018-10-03  1860.36  -325.33    -1136.19
# 3 2018-10-04  1939.02    78.66      403.99
# 4 2018-10-05  1946.17     7.15      -71.51

# %%
plot_comparacao('dia', 'vendas', 'aumento', 'aceleracao', alucel, 'Análise de vendas da Alucel de Outubro e Novembro de 2018')

# %% [markdown]
# **Média Móvel**

# %%
alucel['media_movel'] = alucel['vendas'].rolling(7).mean()

# %%
alucel.head(7)
# Out:
#          dia   vendas  aumento  aceleracao  media_movel
# 0 2018-10-01  1374.83      NaN         NaN          NaN
# 1 2018-10-02  2185.69   810.86         NaN          NaN
# 2 2018-10-03  1860.36  -325.33    -1136.19          NaN
# 3 2018-10-04  1939.02    78.66      403.99          NaN
# 4 2018-10-05  1946.17     7.15      -71.51          NaN
# 5 2018-10-06  2005.89    59.72       52.57          NaN
# 6 2018-10-07  3793.07  1787.18     1727.46  2157.861429

# %%
plotar('Análise de Vendas com Média Móvel de 7 dias', 'Tempo', 'Média Móvel', 'dia', 'media_movel', alucel)

# %%
alucel['media_movel_21'] = alucel['vendas'].rolling(21).mean()

# %%
alucel.head(21)
# Out:
#           dia   vendas  aumento  aceleracao  media_movel  media_movel_21
# 0  2018-10-01  1374.83      NaN         NaN          NaN             NaN
# 1  2018-10-02  2185.69   810.86         NaN          NaN             NaN
# 2  2018-10-03  1860.36  -325.33    -1136.19          NaN             NaN
# 3  2018-10-04  1939.02    78.66      403.99          NaN             NaN
# 4  2018-10-05  1946.17     7.15      -71.51          NaN             NaN
# 5  2018-10-06  2005.89    59.72       52.57          NaN             NaN
# 6  2018-10-07  3793.07  1787.18     1727.46  2157.861429             NaN
# 7  2018-10-08  2039.59 -1753.48    -3540.66  2252.827143             NaN
# 8  2018-10-09  3365.58  1325.99     3079.47  2421.382857             NaN
# 9  2018-10-10  2616.12  -749.46    -2075.45  2529.348571             NaN
# 10 2018-10-11  3745.49  1129.37     1878.83  2787.415714             NaN
# 11 2018-10-12  1578.37 -2167.12    -3296.49  2734.872857             NaN
# 12 2018-10-13  4075.13  2496.76     4663.88  3030.478571             NaN
# 13 2018-10-14  2183.18 -1891.95    -4388.71  2800.494286             NaN
# 14 2018-10-15  3025.13   841.95     2733.90  2941.285714             NaN
# 15 2018-10-16  3176.53   151.40     -690.55  2914.278571             NaN
# 16 2018-10-17  2214.20  -962.33    -1113.73  2856.861429             NaN
# 17 2018-10-18  5163.69  2949.49     3911.82  3059.461429             NaN
# 18 2018-10-19  3787.74 -1375.95    -4325.44  3375.085714             NaN
# 19 2018-10-20  3078.78  -708.96      666.99  3232.750000             NaN
# 20 2018-10-21  5696.93  2618.15     3327.11  3734.714286         2897.69

# %%
plotar('Análise de vendas com média móvel de 21 dias', 'Tempo', 'Média Móvel', 'dia', 'media_movel_21', alucel)

# %%
plot_comparacao('dia', 'vendas', 'media_movel', 'media_movel_21', alucel, 'Comparando as médias móveis')
